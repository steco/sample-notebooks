# %%
from lusidtools.jupyter_tools import toggle_code

"""Cash ladder

Demonstration of how to compute a cash ladder for a portfolio.

Attributes
----------
bucketed cashflow
cash
cash ladder
"""

toggle_code("Toggle Docstring")
# Out:
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Toggle Docstring"></form>
#
#          <script>
#          function code_toggle() {
#              if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                  $('div.cell.code_cell.rendered.selected div.input').hide();
#              } else {
#                  $('div.cell.code_cell.rendered.selected div.input').show();
#              }
#          }
#          </script>

# %% [markdown]
# # Cash Ladder

# %% [markdown]
# In this notebook, we demonstrate how users can create a cash ladder with LUSID. For the purposes of this notebook, we will first upsert a portfolio and some example transactions. Then we will use bucketed cashflows to create a cash ladder. This will help us understand how those transactions have affected our balance over time.
#
# For the purposes of demonstation it is assumed that the current timestamp is 02/04/2020 00:00:00.  This means that there is no data uploaded to LUSID with an effective date after this point (it would be in the "future").

# %% [markdown]
# ## Setup LUSID

# %% [markdown]
# We start by importing relevant libraries, authenticating our user, and creating our API client.

# %%
# Import LUSID packages
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.cocoon.seed_sample_data import seed_data
from lusidjam.refreshing_token import RefreshingToken
from lusid.utilities import ApiClientFactory
import lusid.models as models
import lusid.api as la
import lusid
from IPython.core.display import HTML
from IPython.display import display

# Import general purpose packages
import os
import json
import pandas as pd
import numpy as np
import pytz
import warnings
from datetime import datetime, timedelta

# Configure notebook warnings and pandas display
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# Authenticate our user and create our API client
secrets_path = os.getenv("FBN_SECRETS_PATH")

api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name="LusidJupyterNotebook",
)
api_url = api_factory.api_client.configuration._base_path.replace("api", "")
print("LUSID Environment :", api_url)
# Out:
# LUSID Environment : https://steco.lusid.com/

# %%
# Define the relevant APIs we will use
transaction_portfolio_api = api_factory.build(la.TransactionPortfoliosApi)
quotes_api = api_factory.build(la.QuotesApi)
configuration_recipe_api = api_factory.build(la.ConfigurationRecipeApi)
portfolios_api = api_factory.build(la.PortfoliosApi)
property_definition_api = api_factory.build(la.PropertyDefinitionsApi)

# %% [markdown]
# ## 1. Prepare & Setup Data

# %% [markdown]
# In this notebook, we have a portfolio called EQUITY_FUND. We will create the portfolio with two sub-holding keys, which we will then use later in the notebook to optionally group our cashflows and cash ladder.

# %%
# Portfolio scope and code
scope = "cash-ladder-001"
portfolio_code = "EQUITY_FUND"

# %%
# Create a list containing two property definition objects
property_definitions = []

property_definitions.append(
    models.CreatePropertyDefinitionRequest(
        domain="Transaction",
        scope=scope,
        code="Strategy",
        value_required=False,
        display_name="Strategy",
        data_type_id=models.ResourceId(scope="system", code="string"),
        property_description="The strategy associated with the transaction.",
    )
)

property_definitions.append(
    models.CreatePropertyDefinitionRequest(
        domain="Transaction",
        scope=scope,
        code="CashAccount",
        value_required=False,
        display_name="Cash Account",
        data_type_id=models.ResourceId(scope="system", code="string"),
        property_description="The external cash account associated with the transaction.",
    )
)

# Upsert the property definitions, store the key in another list
sub_holding_key_properties = []

for property_definition in property_definitions:
    # Call LUSID API and log response detail if exception occurs
    try:
        api_response = property_definition_api.create_property_definition(
            create_property_definition_request=property_definition
        )
        # Confirm success
        display(
            f"{api_response.display_name} property definition created successfully."
        )
    except lusid.ApiException as e:
        display(json.loads(e.body)["title"])

    # Store the property keys for future use
    sub_holding_key_properties.append(
        f"{property_definition.domain}/{property_definition.scope}/{property_definition.code}"
    )
# Out:
# "Error creating Property Definition 'Transaction/cash-ladder-001/Strategy' because it already exists."
# "Error creating Property Definition 'Transaction/cash-ladder-001/CashAccount' because it already exists."

# %%
# Load a mapping file for loading data
with open("config/cash_ladder_seed_data.json", "r") as seed_data_config:
    mapping_file = json.loads(seed_data_config.read())

# Load a file of equity transactions
transactions_file = r"data/cash_ladder.csv"
transactions_df = pd.read_csv(transactions_file)
transactions_df["portfolio_code"] = portfolio_code

# Load portfolios, instruments, and transactions
seed_data_response = seed_data(
    api_factory=api_factory,
    domains=["portfolios", "instruments", "transactions"],
    scope=scope,
    transaction_file=transactions_file,
    file_type="csv",
    mappings=mapping_file,
    sub_holding_keys=sub_holding_key_properties,
)

# %% [markdown]
# ## 2. Upload Quote Data

# %% [markdown]
# We will load in some quotes for our equity instruments.

# %%
equity_prices = pd.read_csv("data/equity_quotes.csv")
equity_prices.head(n=5)
# Out:
#   instrument_id     instrument_name        date    price currency
# 0      EQ_GB001            vodafone  29/03/2020   114.60      GBP
# 1      EQ_GB001            vodafone  30/03/2020   114.50      GBP
# 2      EQ_GB001            vodafone  31/03/2020   118.54      GBP
# 3      EQ_GB001            vodafone  01/04/2020   117.64      GBP
# 4      EQ_GB002  Anglo American plc  29/03/2020  1816.40      GBP

# %% [markdown]
# We will then upsert these quotes to LUSID.

# %%
# Iterate through our dataframe and add each quote to an UpsertQuoteRequest
instrument_quotes = {
    index: models.UpsertQuoteRequest(
        quote_id=models.QuoteId(
            quote_series_id=models.QuoteSeriesId(
                provider="Lusid",
                instrument_id=row["instrument_id"],
                instrument_id_type="ClientInternal",
                quote_type="Price",
                field="mid",
            ),
            effective_at=str(
                pytz.timezone("UTC")
                .localize(dt=datetime.strptime(row["date"], "%d/%m/%Y"))
                .isoformat()
            ),
        ),
        metric_value=models.MetricValue(value=row["price"], unit=row["currency"]),
        scale_factor=1,
    )
    for index, row in equity_prices.iterrows()
}

# Upsert the quotes
response = quotes_api.upsert_quotes(scope=scope, request_body=instrument_quotes)

if response.failed == {}:
    display(
        f"Quotes successfully loaded into LUSID. {len(response.values)} quotes loaded."
    )
else:
    display(
        f"Some failures occurred during quote upsertion, {len(response.failed)} did not get loaded into LUSID."
    )
# Out:
# 'Quotes successfully loaded into LUSID. 12 quotes loaded.'

# %% [markdown]
# ## 3. Upsert Configuration Recipe

# %% [markdown]
# Create and upsert basic configuration recipe to be used for valuation.

# %%
# Create a configuration recipe
configuration_recipe = models.ConfigurationRecipe(
    scope=scope,
    code=portfolio_code,
    # Define the market rules and which quotes to use
    market=models.MarketContext(
        market_rules=[
            models.MarketDataKeyRule(
                key="Quote.ClientInternal.*",
                supplier="Lusid",
                data_scope=scope,
                quote_type="Price",
                field="mid",
                quote_interval="2D.0D",
            )
        ],
        options=models.MarketOptions(
            default_supplier="Lusid",
            default_instrument_code_type="ClientInternal",
            default_scope=scope,
        ),
    ),
)

# Upsert the recipe to LUSID
config_recipe_response = configuration_recipe_api.upsert_configuration_recipe(
    upsert_recipe_request=models.UpsertRecipeRequest(
        configuration_recipe=configuration_recipe
    )
)

# %% [markdown]
# ## 4. Produce Cash Ladder

# %% [markdown]
# ### 4.1 Get Bucketed Cash Flows

# %% [markdown]
# We will use the `GetBucketedCashFlows` API endpoint to acquire the data for our cash ladder. This aggregates a transaction portfolio's instruments by date. See API documentation for reference: https://www.lusid.com/docs/api/#operation/GetBucketedCashFlows

# %%
# Set the start and end dates for our cash ladder
start_date = datetime(year=2020, month=4, day=2, tzinfo=pytz.UTC)
end_date = datetime(year=2020, month=4, day=10, tzinfo=pytz.UTC)

# Create a string with the current time
time_now = datetime.utcnow().strftime("%H:%M:%S")

# Create a request to get the bucketed cashflows
bucket_response = transaction_portfolio_api.get_bucketed_cash_flows(
    scope=scope,
    code=portfolio_code,
    bucketed_cash_flow_request=models.BucketedCashFlowRequest(
        # When bucketing, there is not a unique way to allocate the bucket points. Supported options are: [RoundDown, RoundUp]
        rounding_method="RoundDown",
        # List every day between our start and end dates
        bucketing_dates=[
            start_date + timedelta(days=x) for x in range((end_date - start_date).days)
        ],
        # Set the valuation recipe
        recipe_id=models.ResourceId(
            scope=scope,
            code=portfolio_code,
        ),
        # Group by date and currency
        group_by=["Valuation/CashFlowDate/RoundDown",
                  "Valuation/CashFlowCurrency",
                  "Holding/HoldingId"],
        # Add several addresses for more information
        addresses=[
            "Valuation/CashFlowAmount",
            "Valuation/OpenBalance",
            "Valuation/CloseBalance",
            "Valuation/ActivityType",
            "Valuation/Movements",
            "Valuation/SubHoldingKey",
        ],
        # Set effective date, cash flow type, and start window
        effective_at=start_date,
        cash_flow_type="PortfolioCashFlow",
    ),
)

bucket_response
# Out:
# {'data': [{'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0},
#                                                 {'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 20000000.0}],
#            'Append(Valuation/Movements)': ['Open', 'Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 20000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 20000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 20000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 20000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 20000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 20000000.0,
#            'Valuation/OpenBalance': 20000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0},
#                                                 {'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 500000.0},
#                                                 {'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 200000.0}],
#            'Append(Valuation/Movements)': ['Open', 'Side1', 'Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 700000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 700000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 700000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 3000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3700000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 700000.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-05T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3700000.0,
#            'Valuation/OpenBalance': 700000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3700000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 3700000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3700000.0,
#            'Valuation/OpenBalance': 3700000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0},
#                                                 {'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 3000000.0}],
#            'Append(Valuation/Movements)': ['Open', 'Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 3000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3000000.0,
#            'Valuation/OpenBalance': 3000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0},
#                                                 {'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 10000000.0}],
#            'Append(Valuation/Movements)': ['Open', 'Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 10000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 10000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 10000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 10000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 10000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 10000000.0,
#            'Valuation/OpenBalance': 10000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 4000000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 4000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 4000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 4000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 1000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 1000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 5000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 4000000.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-04T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 5000000.0,
#            'Valuation/OpenBalance': 4000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 5000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 5000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 5000000.0,
#            'Valuation/OpenBalance': 5000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 2000000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 2000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDMsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 2000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 2000000.0,
#            'Valuation/OpenBalance': 2000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal003',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 100000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 100000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 100000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 100000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 100000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 100000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 100000.0,
#            'Valuation/OpenBalance': 100000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 1000000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 1000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 1000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 1000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 1000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 1000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 1000000.0,
#            'Valuation/OpenBalance': 1000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 2000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 2000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 2000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 2000000.0,
#            'Valuation/OpenBalance': 2000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': -3000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': -3000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': -3000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': -3000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 20000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 20000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 17000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': -3000000.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-06T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 17000000.0,
#            'Valuation/OpenBalance': -3000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(GBP)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 17000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 17000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'GBP',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 17000000.0,
#            'Valuation/OpenBalance': 17000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 1200000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 1200000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 1200000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 1200000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 3000000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 4200000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 1200000.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-04T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 4200000.0,
#            'Valuation/OpenBalance': 1200000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9SW50ZXJuYWwwMDEsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1TdHJhdGVnaWNHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 4200000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 4200000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 4200000.0,
#            'Valuation/OpenBalance': 4200000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=Internal001',
#                                        'Transaction/cash-ladder-001/Strategy=StrategicGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 3000000.0}],
#            'Append(Valuation/Movements)': ['Side2'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDQsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1FcXVpdHlHcm93dGg=',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 3000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 3000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 3000000.0,
#            'Valuation/OpenBalance': 3000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External004',
#                                        'Transaction/cash-ladder-001/Strategy=EquityGrowth']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Open'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': None,
#            'Valuation/ActivityType': 'Open',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-02T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': 0.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': -2000000.0}],
#            'Append(Valuation/Movements)': ['Side1'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': -2000000.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': -2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': 0.0,
#            'Valuation/ActivityType': 'Activity',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-03T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': -2000000.0,
#            'Valuation/OpenBalance': 0.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']},
#           {'Append(Valuation/CashFlowAmount)': [{'dimension': 0,
#                                                  'resultValueType': 'ResultValue0D',
#                                                  'units': '(USD)',
#                                                  'value': 0.0}],
#            'Append(Valuation/Movements)': ['Closed'],
#            'Holding/HoldingId': 'Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZGRlci0wMDEvQ2FzaEFjY291bnQ9RXh0ZXJuYWwwMDIsIFRyYW5zYWN0aW9uL2Nhc2gtbGFkZGVyLTAwMS9TdHJhdGVneT1SaXNrUmVkdWN0aW9u',
#            'Sum(Valuation/CashFlowAmount)': 0.0,
#            'SumCumulativeInAdvance(Valuation/CashFlowAmount)': -2000000.0,
#            'SumCumulativeInArrears(Valuation/CashFlowAmount)': -2000000.0,
#            'Valuation/ActivityType': 'Closed',
#            'Valuation/CashFlowCurrency': 'USD',
#            'Valuation/CashFlowDate/RoundDown': '2020-04-09T00:00:00.0000000+00:00',
#            'Valuation/CloseBalance': -2000000.0,
#            'Valuation/OpenBalance': -2000000.0,
#            'Valuation/SubHoldingKey': ['Transaction/cash-ladder-001/CashAccount=External002',
#                                        'Transaction/cash-ladder-001/Strategy=RiskReduction']}],
#  'data_schema': {'address_schema': {'Holding/HoldingId': {'description': 'HoldingId',
#                                                           'display_name': 'HoldingId',
#                                                           'documentation_link': '',
# ...
#                                                                  'life_cycle_status': 'Experimental',
#                                                                  'removal_date': None,
#                                                                  'type': 'Decimal'},
#                                     'Valuation/CashFlowCurrency': {'description': 'Documentation '
#                                                                                   'pending',
#                                                                    'display_name': 'Valuation/CashFlowCurrency',
#                                                                    'documentation_link': '',
#                                                                    'life_cycle_status': 'Experimental',
#                                                                    'removal_date': None,
#                                                                    'type': 'String'},
#                                     'Valuation/CashFlowDate/RoundDown': {'description': 'Bucketed '
#                                                                                         'cash '
#                                                                                         'flow '
#                                                                                         'date '
#                                                                                         'by '
#                                                                                         'rounding '
#                                                                                         'down '
#                                                                                         'the '
#                                                                                         'original '
#                                                                                         'cash '
#                                                                                         'flow '
#                                                                                         'date '
#                                                                                         '(given '
#                                                                                         'a '
#                                                                                         'set '
#                                                                                         'of '
#                                                                                         'bucket '
#                                                                                         'points)',
#                                                                          'display_name': 'Bucketed '
#                                                                                          'cash '
#                                                                                          'flow '
#                                                                                          'date',
#                                                                          'documentation_link': '',
#                                                                          'life_cycle_status': 'Experimental',
#                                                                          'removal_date': None,
#                                                                          'type': 'DateTime'},
#                                     'Valuation/CloseBalance': {'description': 'Balance '
#                                                                               'post '
#                                                                               'cash '
#                                                                               'flows',
#                                                                'display_name': 'CloseBalance',
#                                                                'documentation_link': '',
#                                                                'life_cycle_status': 'Experimental',
#                                                                'removal_date': None,
#                                                                'type': 'Decimal'},
#                                     'Valuation/Movements': {'description': 'Name '
#                                                                            'of '
#                                                                            'cash '
#                                                                            'flow '
#                                                                            'movements',
#                                                             'display_name': 'Movement',
#                                                             'documentation_link': '',
#                                                             'life_cycle_status': 'Experimental',
#                                                             'removal_date': None,
#                                                             'type': 'String'},
#                                     'Valuation/OpenBalance': {'description': 'Balance '
#                                                                              'prior '
#                                                                              'cash '
#                                                                              'flows',
#                                                               'display_name': 'OpenBalance',
#                                                               'documentation_link': '',
#                                                               'life_cycle_status': 'Experimental',
#                                                               'removal_date': None,
#                                                               'type': 'Decimal'},
#                                     'Valuation/SubHoldingKey': {'description': 'Documentation '
#                                                                                'pending',
#                                                                 'display_name': 'Valuation/SubHoldingKey',
#                                                                 'documentation_link': '',
#                                                                 'life_cycle_status': 'Experimental',
#                                                                 'removal_date': None,
#                                                                 'type': 'Json'}},
#                  'node_value_schema': None,
#                  'property_schema': {'Holding/HoldingId': {'description': 'HoldingId',
#                                                            'display_name': 'HoldingId',
#                                                            'display_order': 0,
#                                                            'id': {'code': 'Holding/HoldingId',
#                                                                   'scope': 'default'},
#                                                            'type': 'String'},
#                                      'Valuation/ActivityType': {'description': 'Type '
#                                                                                'of '
#                                                                                'activity',
#                                                                 'display_name': 'Valuation/ActivityType',
#                                                                 'display_order': 0,
#                                                                 'id': {'code': 'Valuation/ActivityType',
#                                                                        'scope': 'default'},
#                                                                 'type': 'String'},
#                                      'Valuation/CashFlowAmount': {'description': 'Aggregated '
#                                                                                  'bucketed '
#                                                                                  'cashflow '
#                                                                                  'amount',
#                                                                   'display_name': 'Bucketed '
#                                                                                   'cash '
#                                                                                   'flow '
#                                                                                   'amount',
#                                                                   'display_order': 0,
#                                                                   'id': {'code': 'Valuation/CashFlowAmount',
#                                                                          'scope': 'default'},
#                                                                   'type': 'Decimal'},
#                                      'Valuation/CashFlowCurrency': {'description': 'Documentation '
#                                                                                    'pending',
#                                                                     'display_name': 'Valuation/CashFlowCurrency',
#                                                                     'display_order': 0,
#                                                                     'id': {'code': 'Valuation/CashFlowCurrency',
#                                                                            'scope': 'default'},
#                                                                     'type': 'String'},
#                                      'Valuation/CashFlowDate/RoundDown': {'description': 'Bucketed '
#                                                                                          'cash '
#                                                                                          'flow '
#                                                                                          'date '
#                                                                                          'by '
#                                                                                          'rounding '
#                                                                                          'down '
#                                                                                          'the '
#                                                                                          'original '
#                                                                                          'cash '
#                                                                                          'flow '
#                                                                                          'date '
#                                                                                          '(given '
#                                                                                          'a '
#                                                                                          'set '
#                                                                                          'of '
#                                                                                          'bucket '
#                                                                                          'points)',
#                                                                           'display_name': 'Bucketed '
#                                                                                           'cash '
#                                                                                           'flow '
#                                                                                           'date',
#                                                                           'display_order': 0,
#                                                                           'id': {'code': 'RoundDown',
#                                                                                  'scope': 'CashFlowDate'},
#                                                                           'type': 'DateTime'},
#                                      'Valuation/CloseBalance': {'description': 'Balance '
#                                                                                'post '
#                                                                                'cash '
#                                                                                'flows',
#                                                                 'display_name': 'CloseBalance',
#                                                                 'display_order': 0,
#                                                                 'id': {'code': 'Valuation/CloseBalance',
#                                                                        'scope': 'default'},
#                                                                 'type': 'Decimal'},
#                                      'Valuation/Movements': {'description': 'Name '
#                                                                             'of '
#                                                                             'cash '
#                                                                             'flow '
#                                                                             'movements',
#                                                              'display_name': 'Movement',
#                                                              'display_order': 0,
#                                                              'id': {'code': 'Valuation/Movements',
#                                                                     'scope': 'default'},
#                                                              'type': 'String'},
#                                      'Valuation/OpenBalance': {'description': 'Balance '
#                                                                               'prior '
#                                                                               'cash '
#                                                                               'flows',
#                                                                'display_name': 'OpenBalance',
#                                                                'display_order': 0,
#                                                                'id': {'code': 'Valuation/OpenBalance',
#                                                                       'scope': 'default'},
#                                                                'type': 'Decimal'},
#                                      'Valuation/SubHoldingKey': {'description': 'Documentation '
#                                                                                 'pending',
#                                                                  'display_name': 'Valuation/SubHoldingKey',
#                                                                  'display_order': 0,
#                                                                  'id': {'code': 'Valuation/SubHoldingKey',
#                                                                         'scope': 'default'},
#                                                                  'type': 'String'}}},
#  'failed': {},
#  'href': 'https://steco.lusid.com/api/api/transactionportfolios/cash-ladder-001/EQUITY_FUND/GetBucketedCashFlows/01%2F01%2F0001%2000%3A00%3A00%20%2B00%3A0012%2F31%2F9999%2023%3A59%3A59%20%2B00%3A00?recipeIdCode=EQUITY_FUND&recipeIdScope=cash-ladder-001',
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://steco.lusid.com/app/insights/logs/0HN016EOCR2K8:0000000C',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'report_currency': 'GBP'}

# %% [markdown]
# ### 4.2 Build Cash Ladder

# %% [markdown]
# Now we have our bucketed cashflows, we will extract the cash impacts and create our cash ladder.

# %% [markdown]
# #### Data Preprocessing

# %% [markdown]
# First we need to extract the relevant information from the response.

# %%
# Mapping function used to extract value and unit pairs from a 0D column
def format_result0D_column(values: pd.Series):
    return [(x["value"], x["units"]) for x in values]

# Convert the response to a pandas dataframe
data = pd.DataFrame.from_records(np.array(bucket_response.data))

# Use the mapping function to format CashFlowAmount
data["Append(Valuation/CashFlowAmount)"] = data["Append(Valuation/CashFlowAmount)"].map(
    format_result0D_column
)

# Group rows by currency
data = data.groupby(["Valuation/CashFlowCurrency"], sort=False)

# Define function to convert a dataframe row to a record
def to_record(row):
    # We make use of the CashLadderRecord model
    return models.CashLadderRecord(
        effective_date=pd.to_datetime(row["Valuation/CashFlowDate/RoundDown"]),
        open=row["Valuation/OpenBalance"],
        close=row["Valuation/CloseBalance"],
        activities=list(
            zip(
                row["Append(Valuation/Movements)"],
                row["Append(Valuation/CashFlowAmount)"],
            )
        ),
        
    )
# Out:
#      Valuation/CashFlowDate/RoundDown  \
# 0   2020-04-02T00:00:00.0000000+00:00
# 1   2020-04-09T00:00:00.0000000+00:00
# 2   2020-04-02T00:00:00.0000000+00:00
# 3   2020-04-05T00:00:00.0000000+00:00
# 4   2020-04-09T00:00:00.0000000+00:00
# 5   2020-04-02T00:00:00.0000000+00:00
# 6   2020-04-09T00:00:00.0000000+00:00
# 7   2020-04-02T00:00:00.0000000+00:00
# 8   2020-04-09T00:00:00.0000000+00:00
# 9   2020-04-02T00:00:00.0000000+00:00
# 10  2020-04-03T00:00:00.0000000+00:00
# 11  2020-04-04T00:00:00.0000000+00:00
# 12  2020-04-09T00:00:00.0000000+00:00
# 13  2020-04-02T00:00:00.0000000+00:00
# 14  2020-04-03T00:00:00.0000000+00:00
# 15  2020-04-09T00:00:00.0000000+00:00
# 16  2020-04-02T00:00:00.0000000+00:00
# 17  2020-04-03T00:00:00.0000000+00:00
# 18  2020-04-09T00:00:00.0000000+00:00
# 19  2020-04-02T00:00:00.0000000+00:00
# 20  2020-04-03T00:00:00.0000000+00:00
# 21  2020-04-09T00:00:00.0000000+00:00
# 22  2020-04-02T00:00:00.0000000+00:00
# 23  2020-04-03T00:00:00.0000000+00:00
# 24  2020-04-09T00:00:00.0000000+00:00
# 25  2020-04-02T00:00:00.0000000+00:00
# 26  2020-04-03T00:00:00.0000000+00:00
# 27  2020-04-06T00:00:00.0000000+00:00
# 28  2020-04-09T00:00:00.0000000+00:00
# 29  2020-04-02T00:00:00.0000000+00:00
# 30  2020-04-03T00:00:00.0000000+00:00
# 31  2020-04-04T00:00:00.0000000+00:00
# 32  2020-04-09T00:00:00.0000000+00:00
# 33  2020-04-02T00:00:00.0000000+00:00
# 34  2020-04-03T00:00:00.0000000+00:00
# 35  2020-04-09T00:00:00.0000000+00:00
# 36  2020-04-02T00:00:00.0000000+00:00
# 37  2020-04-03T00:00:00.0000000+00:00
# 38  2020-04-09T00:00:00.0000000+00:00
#
#                      Append(Valuation/CashFlowAmount)  \
# 0                 [(0.0, (USD)), (20000000.0, (USD))]
# 1                                      [(0.0, (USD))]
# 2   [(0.0, (GBP)), (500000.0, (GBP)), (200000.0, (...
# 3                                [(3000000.0, (GBP))]
# 4                                      [(0.0, (GBP))]
# 5                  [(0.0, (USD)), (3000000.0, (USD))]
# 6                                      [(0.0, (USD))]
# 7                 [(0.0, (GBP)), (10000000.0, (GBP))]
# 8                                      [(0.0, (GBP))]
# 9                                      [(0.0, (GBP))]
# 10                               [(4000000.0, (GBP))]
# 11                               [(1000000.0, (GBP))]
# 12                                     [(0.0, (GBP))]
# 13                                     [(0.0, (GBP))]
# 14                               [(2000000.0, (GBP))]
# 15                                     [(0.0, (GBP))]
# 16                                     [(0.0, (GBP))]
# 17                                [(100000.0, (GBP))]
# 18                                     [(0.0, (GBP))]
# 19                                     [(0.0, (GBP))]
# 20                               [(1000000.0, (GBP))]
# 21                                     [(0.0, (GBP))]
# 22                                     [(0.0, (GBP))]
# 23                               [(2000000.0, (GBP))]
# 24                                     [(0.0, (GBP))]
# 25                                     [(0.0, (GBP))]
# 26                              [(-3000000.0, (GBP))]
# 27                              [(20000000.0, (GBP))]
# 28                                     [(0.0, (GBP))]
# 29                                     [(0.0, (USD))]
# 30                               [(1200000.0, (USD))]
# 31                               [(3000000.0, (USD))]
# 32                                     [(0.0, (USD))]
# 33                                     [(0.0, (USD))]
# 34                               [(3000000.0, (USD))]
# 35                                     [(0.0, (USD))]
# 36                                     [(0.0, (USD))]
# 37                              [(-2000000.0, (USD))]
# 38                                     [(0.0, (USD))]
#
#     Sum(Valuation/CashFlowAmount)  \
# 0                      20000000.0
# 1                             0.0
# 2                        700000.0
# 3                       3000000.0
# 4                             0.0
# 5                       3000000.0
# 6                             0.0
# 7                      10000000.0
# 8                             0.0
# 9                             0.0
# 10                      4000000.0
# 11                      1000000.0
# 12                            0.0
# 13                            0.0
# 14                      2000000.0
# 15                            0.0
# 16                            0.0
# 17                       100000.0
# 18                            0.0
# 19                            0.0
# 20                      1000000.0
# 21                            0.0
# 22                            0.0
# 23                      2000000.0
# 24                            0.0
# 25                            0.0
# 26                     -3000000.0
# 27                     20000000.0
# 28                            0.0
# 29                            0.0
# 30                      1200000.0
# 31                      3000000.0
# 32                            0.0
# 33                            0.0
# 34                      3000000.0
# 35                            0.0
# 36                            0.0
# 37                     -2000000.0
# 38                            0.0
#
#     SumCumulativeInAdvance(Valuation/CashFlowAmount)  \
# 0                                         20000000.0
# 1                                         20000000.0
# 2                                           700000.0
# 3                                          3700000.0
# 4                                          3700000.0
# 5                                          3000000.0
# 6                                          3000000.0
# 7                                         10000000.0
# 8                                         10000000.0
# 9                                                0.0
# 10                                         4000000.0
# 11                                         5000000.0
# 12                                         5000000.0
# 13                                               0.0
# 14                                         2000000.0
# 15                                         2000000.0
# 16                                               0.0
# 17                                          100000.0
# 18                                          100000.0
# 19                                               0.0
# 20                                         1000000.0
# 21                                         1000000.0
# 22                                               0.0
# 23                                         2000000.0
# 24                                         2000000.0
# 25                                               0.0
# 26                                        -3000000.0
# 27                                        17000000.0
# 28                                        17000000.0
# 29                                               0.0
# 30                                         1200000.0
# 31                                         4200000.0
# 32                                         4200000.0
# 33                                               0.0
# 34                                         3000000.0
# 35                                         3000000.0
# 36                                               0.0
# 37                                        -2000000.0
# 38                                        -2000000.0
#
#     SumCumulativeInArrears(Valuation/CashFlowAmount) Valuation/ActivityType  \
# 0                                                NaN                   Open
# 1                                         20000000.0                 Closed
# 2                                                NaN                   Open
# 3                                           700000.0               Activity
# 4                                          3700000.0                 Closed
# 5                                                NaN                   Open
# 6                                          3000000.0                 Closed
# 7                                                NaN                   Open
# 8                                         10000000.0                 Closed
# 9                                                NaN                   Open
# 10                                               0.0               Activity
# 11                                         4000000.0               Activity
# 12                                         5000000.0                 Closed
# 13                                               NaN                   Open
# 14                                               0.0               Activity
# 15                                         2000000.0                 Closed
# 16                                               NaN                   Open
# 17                                               0.0               Activity
# 18                                          100000.0                 Closed
# 19                                               NaN                   Open
# 20                                               0.0               Activity
# 21                                         1000000.0                 Closed
# 22                                               NaN                   Open
# 23                                               0.0               Activity
# 24                                         2000000.0                 Closed
# 25                                               NaN                   Open
# 26                                               0.0               Activity
# 27                                        -3000000.0               Activity
# 28                                        17000000.0                 Closed
# 29                                               NaN                   Open
# 30                                               0.0               Activity
# 31                                         1200000.0               Activity
# 32                                         4200000.0                 Closed
# 33                                               NaN                   Open
# 34                                               0.0               Activity
# 35                                         3000000.0                 Closed
# 36                                               NaN                   Open
# 37                                               0.0               Activity
# 38                                        -2000000.0                 Closed
#
#    Append(Valuation/Movements)  \
# 0                [Open, Side1]
# 1                     [Closed]
# 2         [Open, Side1, Side2]
# 3                      [Side1]
# 4                     [Closed]
# 5                [Open, Side2]
# 6                     [Closed]
# 7                [Open, Side1]
# 8                     [Closed]
# 9                       [Open]
# 10                     [Side2]
# 11                     [Side1]
# 12                    [Closed]
# 13                      [Open]
# 14                     [Side2]
# 15                    [Closed]
# 16                      [Open]
# 17                     [Side2]
# 18                    [Closed]
# 19                      [Open]
# 20                     [Side2]
# 21                    [Closed]
# 22                      [Open]
# 23                     [Side1]
# 24                    [Closed]
# 25                      [Open]
# 26                     [Side1]
# 27                     [Side1]
# 28                    [Closed]
# 29                      [Open]
# 30                     [Side2]
# 31                     [Side2]
# 32                    [Closed]
# 33                      [Open]
# 34                     [Side2]
# 35                    [Closed]
# 36                      [Open]
# 37                     [Side1]
# 38                    [Closed]
#
#                               Valuation/SubHoldingKey  \
# 0   [Transaction/cash-ladder-001/CashAccount=Inter...
# 1   [Transaction/cash-ladder-001/CashAccount=Inter...
# 2   [Transaction/cash-ladder-001/CashAccount=Inter...
# 3   [Transaction/cash-ladder-001/CashAccount=Inter...
# 4   [Transaction/cash-ladder-001/CashAccount=Inter...
# 5   [Transaction/cash-ladder-001/CashAccount=Inter...
# 6   [Transaction/cash-ladder-001/CashAccount=Inter...
# 7   [Transaction/cash-ladder-001/CashAccount=Inter...
# 8   [Transaction/cash-ladder-001/CashAccount=Inter...
# 9   [Transaction/cash-ladder-001/CashAccount=Exter...
# 10  [Transaction/cash-ladder-001/CashAccount=Exter...
# 11  [Transaction/cash-ladder-001/CashAccount=Exter...
# 12  [Transaction/cash-ladder-001/CashAccount=Exter...
# 13  [Transaction/cash-ladder-001/CashAccount=Inter...
# 14  [Transaction/cash-ladder-001/CashAccount=Inter...
# 15  [Transaction/cash-ladder-001/CashAccount=Inter...
# 16  [Transaction/cash-ladder-001/CashAccount=Exter...
# 17  [Transaction/cash-ladder-001/CashAccount=Exter...
# 18  [Transaction/cash-ladder-001/CashAccount=Exter...
# 19  [Transaction/cash-ladder-001/CashAccount=Inter...
# 20  [Transaction/cash-ladder-001/CashAccount=Inter...
# 21  [Transaction/cash-ladder-001/CashAccount=Inter...
# 22  [Transaction/cash-ladder-001/CashAccount=Exter...
# 23  [Transaction/cash-ladder-001/CashAccount=Exter...
# 24  [Transaction/cash-ladder-001/CashAccount=Exter...
# 25  [Transaction/cash-ladder-001/CashAccount=Exter...
# 26  [Transaction/cash-ladder-001/CashAccount=Exter...
# 27  [Transaction/cash-ladder-001/CashAccount=Exter...
# 28  [Transaction/cash-ladder-001/CashAccount=Exter...
# 29  [Transaction/cash-ladder-001/CashAccount=Inter...
# 30  [Transaction/cash-ladder-001/CashAccount=Inter...
# 31  [Transaction/cash-ladder-001/CashAccount=Inter...
# 32  [Transaction/cash-ladder-001/CashAccount=Inter...
# 33  [Transaction/cash-ladder-001/CashAccount=Exter...
# 34  [Transaction/cash-ladder-001/CashAccount=Exter...
# 35  [Transaction/cash-ladder-001/CashAccount=Exter...
# 36  [Transaction/cash-ladder-001/CashAccount=Exter...
# 37  [Transaction/cash-ladder-001/CashAccount=Exter...
# 38  [Transaction/cash-ladder-001/CashAccount=Exter...
#
#                                     Holding/HoldingId  \
# 0   Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 1   Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 2   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 3   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 4   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 5   Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 6   Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 7   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 8   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 9   Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 10  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 11  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 12  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 13  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 14  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 15  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 16  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 17  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 18  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 19  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 20  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 21  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 22  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 23  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 24  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 25  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 26  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 27  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 28  Q3VycmVuY3k9R0JQLCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 29  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 30  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 31  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 32  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 33  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 34  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 35  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 36  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 37  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
# 38  Q3VycmVuY3k9VVNELCBUcmFuc2FjdGlvbi9jYXNoLWxhZG...
#
#    Valuation/CashFlowCurrency  Valuation/OpenBalance  Valuation/CloseBalance
# 0                         USD                    0.0              20000000.0
# 1                         USD             20000000.0              20000000.0
# 2                         GBP                    0.0                700000.0
# 3                         GBP               700000.0               3700000.0
# 4                         GBP              3700000.0               3700000.0
# 5                         USD                    0.0               3000000.0
# 6                         USD              3000000.0               3000000.0
# 7                         GBP                    0.0              10000000.0
# 8                         GBP             10000000.0              10000000.0
# 9                         GBP                    0.0                     0.0
# 10                        GBP                    0.0               4000000.0
# 11                        GBP              4000000.0               5000000.0
# 12                        GBP              5000000.0               5000000.0
# 13                        GBP                    0.0                     0.0
# 14                        GBP                    0.0               2000000.0
# 15                        GBP              2000000.0               2000000.0
# 16                        GBP                    0.0                     0.0
# 17                        GBP                    0.0                100000.0
# 18                        GBP               100000.0                100000.0
# 19                        GBP                    0.0                     0.0
# 20                        GBP                    0.0               1000000.0
# 21                        GBP              1000000.0               1000000.0
# 22                        GBP                    0.0                     0.0
# 23                        GBP                    0.0               2000000.0
# 24                        GBP              2000000.0               2000000.0
# 25                        GBP                    0.0                     0.0
# 26                        GBP                    0.0              -3000000.0
# 27                        GBP             -3000000.0              17000000.0
# 28                        GBP             17000000.0              17000000.0
# 29                        USD                    0.0                     0.0
# 30                        USD                    0.0               1200000.0
# 31                        USD              1200000.0               4200000.0
# 32                        USD              4200000.0               4200000.0
# 33                        USD                    0.0                     0.0
# 34                        USD                    0.0               3000000.0
# 35                        USD              3000000.0               3000000.0
# 36                        USD                    0.0                     0.0
# 37                        USD                    0.0              -2000000.0
# 38                        USD             -2000000.0              -2000000.0

# %% [markdown]
# #### Constructing Cash Ladders

# %% [markdown]
# Now we can construct and view the cash ladder for each currency with available quote data. In this case, we have two available: GBP and USD.

# %%
def construct_cash_ladder(data):
    # Iterate through each dataframe group (i.e. currency)
    for key, df in data:
        currency = key[0]
        print(f"Cash ladder for currency {currency}:")

        # Create a new dataframe for each cash ladder
        ladder = pd.DataFrame(
            columns=[
                "ReportRunTime",
                "SettlementDate",
                "Currency",
                "Portfolio",
                "CashLadderStatus",
                "CashImpact",
            ]
        )

        # Iterate through each cash row in our dataframe
        for _, row in df.iterrows():
            if row["Valuation/ActivityType"] != "Activity":
                continue
            # Convert the row to a CashLadderRecord
            record = to_record(row)

            # Create a new row for our SOD balance
            ladder.loc[len(ladder)] = {
                "ReportRunTime": time_now,
                "SettlementDate": record.effective_date.strftime("%Y-%m-%d"),
                "Currency": currency,
                "Portfolio": portfolio_code,
                "CashLadderStatus": "Open Balance",
                "CashImpact": record.open,
            }

            # Iterate through each activity
            for item in record.activities:
                if item[0] != "Closed" and item[0] != "Open":
                    # Create a new row for each cash impact
                    ladder.loc[len(ladder)] = {
                        "ReportRunTime": time_now,
                        "SettlementDate": record.effective_date.strftime("%Y-%m-%d"),
                        "Currency": item[1][1][1:4],
                        "Portfolio": portfolio_code,
                        "CashLadderStatus": f"Cash impact from {item[0]}",
                        "CashImpact": item[1][0],
                    }

            # Create a new row for our EOD balance
            ladder.loc[len(ladder)] = {
                "ReportRunTime": time_now,
                "SettlementDate": record.effective_date.strftime("%Y-%m-%d"),
                "Currency": currency,
                "Portfolio": portfolio_code,
                "CashLadderStatus": "Closed Balance",
                "CashImpact": record.close,
            }

        # Display the cash ladder for this currency
        display(ladder.set_index(["SettlementDate", "Portfolio"]))


construct_cash_ladder(data)

# %% [markdown]
# ### 4.3 Get Filtered Bucketed Cash Flows

# %% [markdown]
# Now we will build another cash ladder, but this time only including transactions using the EquityGrowth Strategy.
#
# First we'll again request Bucketed Cash Flows but with an additional filter provided for the desired sub-holding key.

# %%
# Set the start and end dates for our cash ladder
start_date = datetime(year=2020, month=4, day=2, tzinfo=pytz.UTC)
end_date = datetime(year=2020, month=4, day=10, tzinfo=pytz.UTC)

# Create a string with the current time
time_now = datetime.utcnow().strftime("%H:%M:%S")

# Create a request to get the bucketed cashflows
bucket_response = transaction_portfolio_api.get_bucketed_cash_flows(
    scope=scope,
    code=portfolio_code,
    bucketed_cash_flow_request=models.BucketedCashFlowRequest(
        # When bucketing, there is not a unique way to allocate the bucket points. Supported options are: [RoundDown, RoundUp]
        rounding_method="RoundDown",
        # List every day between our start and end dates
        bucketing_dates=[
            start_date + timedelta(days=x) for x in range((end_date - start_date).days)
        ],
        # Set the valuation recipe
        recipe_id=models.ResourceId(
            scope=scope,
            code=portfolio_code,
        ),
        # Group by date and currency
        group_by=["Valuation/CashFlowDate/RoundDown",
                  "Valuation/CashFlowCurrency"],
        # Add several addresses for more information
        addresses=[
            "Valuation/CashFlowAmount",
            "Valuation/OpenBalance",
            "Valuation/CloseBalance",
            "Valuation/ActivityType",
            "Valuation/Movements",
        ],
        # Set effective date, cash flow type, and start window
        effective_at=start_date,
        cash_flow_type="PortfolioCashFlow",
        filter=f"subHoldingKeys.Transaction/{scope}/Strategy eq 'EquityGrowth'",
    ),
)

# Convert the response to a pandas dataframe
data = pd.DataFrame.from_records(np.array(bucket_response.data))

# Use the mapping function to format CashFlowAmount
data["Append(Valuation/CashFlowAmount)"] = data["Append(Valuation/CashFlowAmount)"].map(
    format_result0D_column
)

# Group rows by currency
data = data.groupby(["Valuation/CashFlowCurrency"], sort=False)

# %% [markdown]
# With a new response in our dataframe, we can call the previously defined functions again to build and display our cash ladder.

# %%
construct_cash_ladder(data)
# Out:
# Cash ladder for currency GBP:
#                            ReportRunTime Currency        CashLadderStatus  \
# SettlementDate Portfolio
# 2020-04-03     EQUITY_FUND      08:47:15      GBP            Open Balance
#                EQUITY_FUND      08:47:15      GBP  Cash impact from Side2
#                EQUITY_FUND      08:47:15      GBP  Cash impact from Side1
#                EQUITY_FUND      08:47:15      GBP          Closed Balance
# 2020-04-04     EQUITY_FUND      08:47:15      GBP            Open Balance
#                EQUITY_FUND      08:47:15      GBP  Cash impact from Side1
#                EQUITY_FUND      08:47:15      GBP          Closed Balance
# 2020-04-05     EQUITY_FUND      08:47:15      GBP            Open Balance
#                EQUITY_FUND      08:47:15      GBP  Cash impact from Side1
#                EQUITY_FUND      08:47:15      GBP          Closed Balance
# 2020-04-06     EQUITY_FUND      08:47:15      GBP            Open Balance
#                EQUITY_FUND      08:47:15      GBP  Cash impact from Side1
#                EQUITY_FUND      08:47:15      GBP          Closed Balance
#
#                             CashImpact
# SettlementDate Portfolio
# 2020-04-03     EQUITY_FUND    700000.0
#                EQUITY_FUND   6000000.0
#                EQUITY_FUND  -3000000.0
#                EQUITY_FUND   3700000.0
# 2020-04-04     EQUITY_FUND   3700000.0
#                EQUITY_FUND   1000000.0
#                EQUITY_FUND   4700000.0
# 2020-04-05     EQUITY_FUND   4700000.0
#                EQUITY_FUND   3000000.0
#                EQUITY_FUND   7700000.0
# 2020-04-06     EQUITY_FUND   7700000.0
#                EQUITY_FUND  20000000.0
#                EQUITY_FUND  27700000.0
# Cash ladder for currency USD:
#                            ReportRunTime Currency        CashLadderStatus  \
# SettlementDate Portfolio
# 2020-04-03     EQUITY_FUND      08:47:15      USD            Open Balance
#                EQUITY_FUND      08:47:15      USD  Cash impact from Side2
#                EQUITY_FUND      08:47:15      USD          Closed Balance
#
#                             CashImpact
# SettlementDate Portfolio
# 2020-04-03     EQUITY_FUND   3000000.0
#                EQUITY_FUND   3000000.0
#                EQUITY_FUND   6000000.0

# %%
display(HTML("<h2>5. Links</h2>"))

display(
    HTML(
        f'<a href="{api_url}app/dashboard/transactions?scope=cash-ladder-001&code=EQUITY_FUND&entityType=Portfolio&effectiveDate=2023-10-17T16:03:24.218Z&dateFrom=2000-01-01T00:00:00.000Z&dateTo=2023-10-17T16:03:24.218Z&taxLots=false&withOrders=false&withAllocations=false&dashboardType=input&showNonActiveTransactions=false" target="_blank">Transactions</a>'
    )
)

display(
    HTML(
        f'<a href="{api_url}app/dashboard/cash-ladder?scope=cash-ladder-001&code=EQUITY_FUND&entityType=Portfolio&recipeScope=cash-ladder-001&recipeCode=EQUITY_FUND&effectiveDate=2020-04-01T23:01:00.000Z&fromDate=2020-04-01T23:00:00.000Z&toDate=2023-10-31T23:59:59.999Z&allDates=false" target="_blank">Cash Ladder</a>'
    )
)
# Out:
# <h2>5. Links</h2>
# <a href="https://steco.lusid.com/app/dashboard/transactions?scope=cash-ladder-001&code=EQUITY_FUND&entityType=Portfolio&effectiveDate=2023-10-17T16:03:24.218Z&dateFrom=2000-01-01T00:00:00.000Z&dateTo=2023-10-17T16:03:24.218Z&taxLots=false&withOrders=false&withAllocations=false&dashboardType=input&showNonActiveTransactions=false" target="_blank">Transactions</a>
# <a href="https://steco.lusid.com/app/dashboard/cash-ladder?scope=cash-ladder-001&code=EQUITY_FUND&entityType=Portfolio&recipeScope=cash-ladder-001&recipeCode=EQUITY_FUND&effectiveDate=2020-04-01T23:01:00.000Z&fromDate=2020-04-01T23:00:00.000Z&toDate=2023-10-31T23:59:59.999Z&allDates=false" target="_blank">Cash Ladder</a>

# %%
# Out:
# Requirement already satisfied: lusid-sdk-preview in /opt/conda/lib/python3.11/site-packages (1.1.41)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (2023.7.22)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (2.8.2)
# Requirement already satisfied: urllib3>=1.26.9 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (2.0.7)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (2.31.0)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.11/site-packages (from lusid-sdk-preview) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27.1->lusid-sdk-preview) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27.1->lusid-sdk-preview) (3.4)
# Note: you may need to restart the kernel to use updated packages.
